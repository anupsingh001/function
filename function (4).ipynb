# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#
# A function is a block of reusable code that performs a specific task and is defined using the def keyword.
#
# A method is a function that is associated with an object and is called on that object (e.g., list.append()). Methods belong to classes.
#
#
#
# ---
#
# 2. Explain the concept of function arguments and parameters in Python.
#
# Parameters are the variable names listed in a function’s definition.
#
# Arguments are the actual values passed to the function when it is called.
#
#
#
# ---
#
# 3. What are the different ways to define and call a function in Python?
#
# Define using def or lambda.
#
# Call with function_name(arguments).
# Example:
#
#
# def greet(name):
#     return f"Hello, {name}"
#
# greet("Alice")
#
#
# ---
#
# 4. What is the purpose of the return statement in a Python function?
#
# It sends a result back to the caller and ends the function execution. It can return any object or value.
#
#
#
# ---
#
# 5. What are iterators in Python and how do they differ from iterables?
#
# An iterable is any object you can loop over (e.g., list, tuple).
#
# An iterator is an object with a _next_() method. It retrieves one element at a time from an iterable.
#
#
#
# ---
#
# 6. Explain the concept of generators in Python and how they are defined.
#
# A generator is a function that yields values one at a time using yield instead of return. It produces values lazily, saving memory.
#
#
# Example:
#
# def countdown(n):
#     while n > 0:
#         yield n
#         n -= 1
#
#
# ---
#
# 7. What are the advantages of using generators over regular functions?
#
# Memory efficient (no need to store entire data in memory).
#
# Computation is done on-the-fly.
#
# Useful for large datasets and streaming data.
#
#
#
# ---
#
# 8. What is a lambda function in Python and when is it typically used?
#
# A lambda function is an anonymous, single-expression function.
# Example:
#
#
# square = lambda x: x * x
#
# Used for short, simple functions especially in map(), filter(), etc.
#
#
#
# ---
#
# 9. Explain the purpose and usage of the map() function in Python.
#
# map() applies a function to all items in an iterable.
# Example:
#
#
# numbers = [1, 2, 3]
# squared = list(map(lambda x: x**2, numbers))
#
#
# ---
#
# 10. What is the difference between map(), reduce(), and filter() functions in Python?
#
# map() transforms each element.
#
# filter() selects elements based on a condition.
#
# reduce() (from functools) combines elements into a single result.
#
#
# Example:
#
# from functools import reduce
#
# reduce(lambda x, y: x + y, [1, 2, 3])  # Output: 6
#
#
# ---
#
# 11. Using pen & paper, write the internal mechanism for sum operation using reduce() on [47, 1, 42, 13]
#
# For this part, please write the steps on paper and take a photo of it. Then upload the image here, and I’ll help you analyze or improve it if needed. Would you like a sample format to copy onto your paper?

# %%
1. Sum of all even numbers in a list:

def sum_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)


---

2. Reverse a string:

def reverse_string(s):
    return s[::-1]


---

3. Squares of each number in a list:

def square_list(numbers):
    return [x**2 for x in numbers]


---

4. Check if a number is prime (1 to 200):

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True

# Check all primes from 1 to 200
primes = [x for x in range(1, 201) if is_prime(x)]


---

5. Fibonacci iterator class:

class Fibonacci:
    def _init_(self, max_terms):
        self.max_terms = max_terms
        self.a, self.b = 0, 1
        self.count = 0

    def _iter_(self):
        return self

    def _next_(self):
        if self.count >= self.max_terms:
            raise StopIteration
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return self.a


---

6. Generator for powers of 2:

def powers_of_two(n):
    for i in range(n+1):
        yield 2 ** i


---

7. Generator that yields lines from a file:

def read_lines(filename):
    with open(filename, 'r') as file:
        for line in file:
            yield line.strip()


---

8. Sort list of tuples by second element using lambda:

tuples_list = [(1, 3), (2, 1), (4, 2)]
sorted_list = sorted(tuples_list, key=lambda x: x[1])


---

9. Convert Celsius to Fahrenheit using map():

celsius = [0, 10, 20, 30]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))


---

10. Remove vowels from a string using filter():

def remove_vowels(s):
    return ''.join(filter(lambda x: x.lower() not in 'aeiou', s))


---

11.. orders = [
    [34587, "Learning Python, Mark Lutz", 1, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

# Compute order value and apply €10 charge if under €100
result = list(map(lambda order: (
    order[0],
    round(order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0
